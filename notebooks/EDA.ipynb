# %% [markdown]
# # Exploratory Data Analysis - Climate Trends
# This notebook explores the correlation between CO2 levels and Global Temperature Spikes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/Cleaned_Climate_Data.csv')
plt.plot(df['year'], df['temperature'])
plt.show()
